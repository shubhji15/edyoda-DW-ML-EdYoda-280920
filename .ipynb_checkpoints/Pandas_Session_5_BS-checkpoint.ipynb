# %% [markdown]
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## This is the data given as a dictionary

# %%
# Create an example dataframe about a fictional army
raw_data = {'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia'],
            'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3]}

# %% [markdown]
# ## Create a dataframe and assign it to a variable called army.

# %%
army = pd.DataFrame(raw_data)

# %%
army
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 0      Arizona  Nighthawks     1st     523        5  1045         1
# 1   California  Nighthawks     1st      52       42   957         5
# 2        Texas  Nighthawks     2nd      25        2  1099        62
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 4        Maine    Dragoons     1st      43        4  1592        73
# 5         Iowa    Dragoons     1st     234        7  1006        37
# 6       Alaska    Dragoons     2nd     523        8   987       949
# 7   Washington    Dragoons     2nd      62        3   849        48
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 0           1        1          4
# 1           2        0         24
# 2           3        1         31
# 3           3        1          2
# 4           2        0          3
# 5           1        1          4
# 6           2        0         24
# 7           3        1         31
# 8           2        0          2
# 9           1        0          3
# 10          2        1          2
# 11          3        1          3

# %% [markdown]
# ##  Set the 'origin' colum as the index of the dataframe

# %%
army.set_index('origin', inplace = True)

# %%
army.reset_index()
# Out:
#         origin    regiment company  deaths  battles  size  veterans  \
# 0      Arizona  Nighthawks     1st     523        5  1045         1
# 1   California  Nighthawks     1st      52       42   957         5
# 2        Texas  Nighthawks     2nd      25        2  1099        62
# 3      Florida  Nighthawks     2nd     616        2  1400        26
# 4        Maine    Dragoons     1st      43        4  1592        73
# 5         Iowa    Dragoons     1st     234        7  1006        37
# 6       Alaska    Dragoons     2nd     523        8   987       949
# 7   Washington    Dragoons     2nd      62        3   849        48
# 8       Oregon      Scouts     1st      62        4   973        48
# 9      Wyoming      Scouts     1st      73        7  1005       435
# 10    Louisana      Scouts     2nd      37        8  1099        63
# 11     Georgia      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters
# 0           1        1          4
# 1           2        0         24
# 2           3        1         31
# 3           3        1          2
# 4           2        0          3
# 5           1        1          4
# 6           2        0         24
# 7           3        1         31
# 8           2        0          2
# 9           1        0          3
# 10          2        1          2
# 11          3        1          3

# %% [markdown]
# ## Sort the dataframe by company

# %%
army.sort_values(by ='company')
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Maine             0          3
# Iowa              1          4
# Oregon            0          2
# Wyoming           0          3
# Texas             1         31
# Florida           1          2
# Alaska            0         24
# Washington        1         31
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ## Sort the dataframe by deaths

# %%
army.sort_values(by = 'deaths', ascending = False)
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Arizona     Nighthawks     1st     523        5  1045         1          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Wyoming         Scouts     1st      73        7  1005       435          1
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# California  Nighthawks     1st      52       42   957         5          2
# Maine         Dragoons     1st      43        4  1592        73          2
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
# Texas       Nighthawks     2nd      25        2  1099        62          3
#
#             armored  deserters
# origin
# Florida           1          2
# Arizona           1          4
# Alaska            0         24
# Iowa              1          4
# Wyoming           0          3
# Washington        1         31
# Oregon            0          2
# California        0         24
# Maine             0          3
# Louisana          1          2
# Georgia           1          3
# Texas             1         31

# %%
army.sort_values(by=['company', 'deaths'])
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine         Dragoons     1st      43        4  1592        73          2
# California  Nighthawks     1st      52       42   957         5          2
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Iowa          Dragoons     1st     234        7  1006        37          1
# Arizona     Nighthawks     1st     523        5  1045         1          1
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Georgia         Scouts     2nd      35        9  1523       345          3
# Louisana        Scouts     2nd      37        8  1099        63          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Alaska        Dragoons     2nd     523        8   987       949          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Maine             0          3
# California        0         24
# Oregon            0          2
# Wyoming           0          3
# Iowa              1          4
# Arizona           1          4
# Texas             1         31
# Georgia           1          3
# Louisana          1          2
# Washington        1         31
# Alaska            0         24
# Florida           1          2

# %% [markdown]
# # Fitering columns

# %% [markdown]
# ## Based on names/labels

# %% [markdown]
# ### Print the name of all the columns.

# %%
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Print only the column battles

# %%
army['battles'] = army['battles']+2

# %% [markdown]
# ### Print the columns 'regiment' and 'deaths'

# %%
army_deaths = army[['regiment', 'deaths']]

# %%
army_deaths
# Out:
#               regiment  deaths
# origin
# Arizona     Nighthawks     523
# California  Nighthawks      52
# Texas       Nighthawks      25
# Florida     Nighthawks     616
# Maine         Dragoons      43
# Iowa          Dragoons     234
# Alaska        Dragoons     523
# Washington    Dragoons      62
# Oregon          Scouts      62
# Wyoming         Scouts      73
# Louisana        Scouts      37
# Georgia         Scouts      35

# %% [markdown]
# ## Based on type

# %% [markdown]
# ### Print dtypes of all columns

# %%
army.dtypes
# Out:
# regiment     object
# company      object
# deaths        int64
# battles       int64
# size          int64
# veterans      int64
# readiness     int64
# armored       int64
# deserters     int64
# dtype: object

# %%
army['armored'].astype('object')      #changing the datatype of the columns int to object datatype.
# Out:
# origin
# Arizona       1
# California    0
# Texas         1
# Florida       1
# Maine         0
# Iowa          1
# Alaska        0
# Washington    1
# Oregon        0
# Wyoming       0
# Louisana      1
# Georgia       1
# Name: armored, dtype: object

# %% [markdown]
# ### Select columns of only object type

# %%
army_cat = army.select_dtypes(include = ['object'])

# %%
army_cat
# Out:
#               regiment company
# origin
# Arizona     Nighthawks     1st
# California  Nighthawks     1st
# Texas       Nighthawks     2nd
# Florida     Nighthawks     2nd
# Maine         Dragoons     1st
# Iowa          Dragoons     1st
# Alaska        Dragoons     2nd
# Washington    Dragoons     2nd
# Oregon          Scouts     1st
# Wyoming         Scouts     1st
# Louisana        Scouts     2nd
# Georgia         Scouts     2nd

# %% [markdown]
# ### Select columns of only int type

# %%
army_int = army.select_dtypes(include=['int64'])

# %%
pd.merge(army_cat.reset_index(), army_int.reset_index(), how='inner',on='origin').set_index('origin')
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        7  1045         1          1
# California  Nighthawks     1st      52       44   957         5          2
# Texas       Nighthawks     2nd      25        4  1099        62          3
# Florida     Nighthawks     2nd     616        4  1400        26          3
# Maine         Dragoons     1st      43        6  1592        73          2
# Iowa          Dragoons     1st     234        9  1006        37          1
# Alaska        Dragoons     2nd     523       10   987       949          2
# Washington    Dragoons     2nd      62        5   849        48          3
# Oregon          Scouts     1st      62        6   973        48          2
# Wyoming         Scouts     1st      73        9  1005       435          1
# Louisana        Scouts     2nd      37       10  1099        63          2
# Georgia         Scouts     2nd      35       11  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ## Based on conditions

# %% [markdown]
# ### Select rows where df.deaths is greater than 50

# %%
army[army['deaths']>50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        7  1045         1          1
# California  Nighthawks     1st      52       44   957         5          2
# Florida     Nighthawks     2nd     616        4  1400        26          3
# Iowa          Dragoons     1st     234        9  1006        37          1
# Alaska        Dragoons     2nd     523       10   987       949          2
# Washington    Dragoons     2nd      62        5   849        48          3
# Oregon          Scouts     1st      62        6   973        48          2
# Wyoming         Scouts     1st      73        9  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3

# %% [markdown]
# ### Select rows where df.deaths is greater than 500 or less than 50

# %%
army[(army['deaths']>500) | (army['deaths']<50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        7  1045         1          1
# Texas     Nighthawks     2nd      25        4  1099        62          3
# Florida   Nighthawks     2nd     616        4  1400        26          3
# Maine       Dragoons     1st      43        6  1592        73          2
# Alaska      Dragoons     2nd     523       10   987       949          2
# Louisana      Scouts     2nd      37       10  1099        63          2
# Georgia       Scouts     2nd      35       11  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %% [markdown]
# ### Select all the regiments  equal to "Scouts"

# %%
army[army['regiment']=='Scouts']
# Out:
#          regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Oregon     Scouts     1st      62        6   973        48          2
# Wyoming    Scouts     1st      73        9  1005       435          1
# Louisana   Scouts     2nd      37       10  1099        63          2
# Georgia    Scouts     2nd      35       11  1523       345          3
#
#           armored  deserters
# origin
# Oregon          0          2
# Wyoming         0          3
# Louisana        1          2
# Georgia         1          3

# %% [markdown]
# ### Select all the regiments not equal "Dragoons"

# %%
army[army['regiment']!='Dragoons']
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        7  1045         1          1
# California  Nighthawks     1st      52       44   957         5          2
# Texas       Nighthawks     2nd      25        4  1099        62          3
# Florida     Nighthawks     2nd     616        4  1400        26          3
# Oregon          Scouts     1st      62        6   973        48          2
# Wyoming         Scouts     1st      73        9  1005       435          1
# Louisana        Scouts     2nd      37       10  1099        63          2
# Georgia         Scouts     2nd      35       11  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# # Filtering rows using loc & iloc

# %% [markdown]
# ## LOC func - Use loc[ ] to choose rows and columns by label.
#
# **loc is label-based, which means that you have to specify rows and columns based on their row and column labels**

# %% [markdown]
# ### Select the rows called Texas and Arizona

# %%
army.loc[['Texas','Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        4  1099        62          3
# Arizona  Nighthawks     1st     523        7  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ## ILOC func - Use iloc[ ] to choose rows and columns by position.
#
# **iloc is integer index based, so you have to specify rows and columns by their integer index**

# %% [markdown]
# ### Select the first 3 rows

# %%
army.iloc[0:3]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        7  1045         1          1
# California  Nighthawks     1st      52       44   957         5          2
# Texas       Nighthawks     2nd      25        4  1099        62          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31

# %% [markdown]
# # Filtering both rows & columns using loc & iloc

# %%
army.iloc[0:3,0:3]
# Out:
#               regiment company  deaths
# origin
# Arizona     Nighthawks     1st     523
# California  Nighthawks     1st      52
# Texas       Nighthawks     2nd      25

# %% [markdown]
# ### Select the 'Alaska' from index and 'deaths' from columns

# %%
army.loc['Alaska','deaths']
# Out:
# 523

# %% [markdown]
# ### Select the 'Maine' and 'Alaska' from index and 'deaths', 'size' and 'deserters' from columns

# %%
army.loc[['Maine','Alaska'],['deaths','size','desertes']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-9c88adc79845> in <module>
# ----> 1 army.iloc[['Maine','Alaska'],['deaths','size','desertes']]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1418             # check that the key has a numeric dtype
#    1419             if not is_numeric_dtype(arr.dtype):
# -> 1420                 raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1421
#    1422             # check that the key does not exceed the maximum size of the index
#
# IndexError: .iloc requires numeric indexers, got ['Maine' 'Alaska']

# %% [markdown]
# ### Select the rows 3 to 7 and the columns 3 to 6

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        7  1045         1          1
# California  Nighthawks     1st      52       44   957         5          2
# Texas       Nighthawks     2nd      25        4  1099        62          3
# Florida     Nighthawks     2nd     616        4  1400        26          3
# Maine         Dragoons     1st      43        6  1592        73          2
# Iowa          Dragoons     1st     234        9  1006        37          1
# Alaska        Dragoons     2nd     523       10   987       949          2
# Washington    Dragoons     2nd      62        5   849        48          3
# Oregon          Scouts     1st      62        6   973        48          2
# Wyoming         Scouts     1st      73        9  1005       435          1
# Louisana        Scouts     2nd      37       10  1099        63          2
# Georgia         Scouts     2nd      35       11  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %%
army.iloc[2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        4  1099        62
# Florida     616        4  1400        26
# Maine        43        6  1592        73
# Iowa        234        9  1006        37
# Alaska      523       10   987       949

# %%
army.iloc[3:7]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Florida  Nighthawks     2nd     616        4  1400        26          3
# Maine      Dragoons     1st      43        6  1592        73          2
# Iowa       Dragoons     1st     234        9  1006        37          1
# Alaska     Dragoons     2nd     523       10   987       949          2
#
#          armored  deserters
# origin
# Florida        1          2
# Maine          0          3
# Iowa           1          4
# Alaska         0         24

# %% [markdown]
# ### Select every row after the fourth row and all columns

# %%
army.iloc[4]
# Out:
# regiment     Dragoons
# company           1st
# deaths             43
# battles             6
# size             1592
# veterans           73
# readiness           2
# armored             0
# deserters           3
# Name: Maine, dtype: object

# %% [markdown]
# ###  Select every row up to the 4th row and all columns

# %%
army.iloc[0:4, :]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        7  1045         1          1
# California  Nighthawks     1st      52       44   957         5          2
# Texas       Nighthawks     2nd      25        4  1099        62          3
# Florida     Nighthawks     2nd     616        4  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ### Select the 3rd column up to the 7th column

# %%
army.iloc[:, 2:7]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        7  1045         1          1
# California      52       44   957         5          2
# Texas           25        4  1099        62          3
# Florida        616        4  1400        26          3
# Maine           43        6  1592        73          2
# Iowa           234        9  1006        37          1
# Alaska         523       10   987       949          2
# Washington      62        5   849        48          3
# Oregon          62        6   973        48          2
# Wyoming         73        9  1005       435          1
# Louisana        37       10  1099        63          2
# Georgia         35       11  1523       345          3

# %%
#######################################################END OF SESSION  ############################################
